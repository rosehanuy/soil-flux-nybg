# %%
import pandas as pd
import statsmodels.api as sm
from patsy import dmatrices

# %%
import os

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### For each collar, plot Flux v. Soil Temp and Flux v. Chamber Temp

# %%
basepath = 'C:/Users/roseh/Desktop/NYBG_R/'
file_location = 'data/processed/QC2'
os.chdir(os.path.join(basepath, file_location))

# %%
df = pd.read_csv('NYBG_CO2_Flux_and_Temps.csv')

# %%
df.drop(22,axis=0,inplace=True)

# %%
grouped = df.groupby('Collar')

# %%
def plot_temps(collar):
    """Make side-by-side plots of CO2 flux v. Soil Temperature 
    and CO2 flux v. Chamber Temperature"""
    
    fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,3))
    
    ax1.scatter(collar[1]['Temperature'],collar[1]['CO2_Flux'])
    ax1.set_title('{}: CO2 v. Soil Temperature'.format(collar[0]))
    ax2.scatter(collar[1]['Chamber_Temp'],collar[1]['CO2_Flux'])
    ax2.set_title('{}: CO2 v. Chamber Temperature'.format(collar[0]))
    
    filepath = 'C:/Users/roseh/Desktop/NYBG_R/data/processed/QC2/collar_plots'
    filename = '{} chamber_soil_temp_plots.png'.format(collar[0])
    plt.savefig(os.path.join(filepath,filename))
    plt.show()

# %%
collar_list = [group for group in grouped]

# %%
for collar in collar_list:
    plot_temps(collar)

# %% [markdown]
# #### For each land type, plot Flux v. Soil Temp and Flux v. Chamber Temp

# %%
grouped_2 = df.groupby('Type')

# %%
type_list = [group for group in grouped_2]

# %%
for collar in type_list:
    plot_temps(collar)
