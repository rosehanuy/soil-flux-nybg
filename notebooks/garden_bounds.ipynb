# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ### Finding the garden boundaries.

# %%
data_path = r'C:\Users\roseh\Desktop\NYBG_R\data\processed\park_boundaries'

# %%
gdf = gpd.read_file(os.path.join(data_path,'geo_export_2f217d6a-38c5-46ef-86f1-d43ee072c7d9.shp'))

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2033 entries, 0 to 2032
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   acquisitio  1945 non-null   object
#  1   acres       2033 non-null   float64
#  2   address     1194 non-null   object
#  3   borough     2033 non-null   object
#  4   class       2033 non-null   object
#  5   communityb  2033 non-null   float64
#  6   councildis  2033 non-null   float64
#  7   department  2033 non-null   object
#  8   eapply      1945 non-null   object
#  9   gisobjid    2031 non-null   float64
#  10  gispropnum  2033 non-null   object
#  11  globalid    2033 non-null   object
#  12  jurisdicti  2033 non-null   object
#  13  location    2033 non-null   object
#  14  mapped      2033 non-null   object
#  15  name311     2032 non-null   object
#  16  nys_assemb  2033 non-null   float64
#  17  nys_senate  2031 non-null   float64
# ...

# %%
gdf.loc[gdf['borough'] == 'X'].plot()
# Out:
# <AxesSubplot: >

# %%
bronx = gdf.loc[gdf['borough'] == 'X']

# %%
bronx.head()
# Out:
#                      acquisitio   acres address borough class  communityb  \
# 3   1969-10-09 00:00:00.0000000   0.042    None       X  PARK       209.0
# 38  1938-03-08 00:00:00.0000000   0.313    None       X  PARK       201.0
# 45  1888-12-12 00:00:00.0000000  80.936    None       X  PARK    207208.0
# 46  2002-11-20 00:00:00.0000000   0.096    None       X  PARK       206.0
# 55  1844-07-09 00:00:00.0000000   0.444    None       X  PARK       210.0
#
#     councildis department                      eapply     gisobjid  ...  \
# 3         13.0       X-09                        Park  100008357.0  ...
# 38         8.0       X-01  Gouverneur Morris Triangle  100004413.0  ...
# 45        11.0       X-07             Mosholu Parkway  100004211.0  ...
# 46        17.0       X-06            Mohegan Triangle  100007370.0  ...
# 55        13.0       X-10            Throgs Neck Park  100004034.0  ...
#
#    precinct retired                    signname                  subcategor  \
# ...

# %%
bronx.loc[bronx['acres']>200]
# Out:
#                        acquisitio     acres             address borough class  \
# 108   1888-12-12 00:00:00.0000000  2771.747                None       X  PARK
# 193   1960-12-05 00:00:00.0000000   229.140                None       X  PARK
# 352   1937-09-13 00:00:00.0000000   205.310                None       X  PARK
# 1700  1888-12-08 00:00:00.0000000   718.373    2120 BOSTON ROAD       X  PARK
# 1793  1925-12-31 00:00:00.0000000   206.717                None       X  PARK
# 1925  1888-12-12 00:00:00.0000000  1146.430  3545 JEROME AVENUE       X  PARK
# 2018  1937-07-22 00:00:00.0000000   413.800                None       X  PARK
#
#         communityb  councildis department                             eapply  \
# 108   2.102120e+05      1213.0       X-15  Pelham Bay Park and Orchard Beach
# 193   2.102110e+05      1213.0       X-10           Hutchinson River Parkway
# 352   2.090000e+02        18.0       X-09                     Soundview Park
# ...

# %%
garden = bronx.loc[bronx['signname']=='Bronx Park']

# %%
garden.to_file(os.path.join(data_path,'garden_bounds.shp'))

# %%
polygons = [poly for poly in garden['geometry']]

# %%
polygons

# %%
list(polygons)

# %%
max(polygons, key=lambda a: a.area)
