# %%
# for xxxx.x81 files
# Remove rows with elapse time of -1
# Create a new file named with qc1 meaning quality control level 1
Datadir ='/Users/dandanwei/Desktop/Measurements-2022/SoilFlux/data/Raw_Data_2022701/'
filename='NYBG_220831.81x'
newfile ='NYBG_220831_qc1.81x'

with open(Datadir+filename, "r") as old_file:
    with open(Datadir+newfile, "w") as output: 
        for line in old_file:
            if '\t'+'-1'+'\t' in line:
                print(line[0:20])
            else:
                output.write(line)
# Out:
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 08:5
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# 1	-1	2022-08-31 09:0
# ...
